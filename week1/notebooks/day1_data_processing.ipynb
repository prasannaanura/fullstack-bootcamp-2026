# %%
# Student data
students = [
    {"name": "Alice", "grade": 85, "subject": "Math"},
    {"name": "Bob", "grade": 62, "subject": "Math"},
    {"name": "Charlie", "grade": 92, "subject": "Science"},
    {"name": "Diana", "grade": 78, "subject": "Math"},
    {"name": "Edward", "grade": 55, "subject": "Science"},
    {"name": "Fiona", "grade": 88, "subject": "Math"},
    {"name": "George", "grade": 91, "subject": "Science"},
    {"name": "Hannah", "grade": 73, "subject": "Math"},
    {"name": "Ian", "grade": 67, "subject": "Science"},
    {"name": "Julia", "grade": 95, "subject": "Math"},
    {"name":"anne","grade":90,"subject":"IT"},
]

print(f"Total students: {len(students)}")
print(f"First student: {students[0]}")
print(f"second student: {students[1]}")
# Out:
# Total students: 11
# First student: {'name': 'Alice', 'grade': 85, 'subject': 'Math'}
# second student: {'name': 'Bob', 'grade': 62, 'subject': 'Math'}

# %%
marks_ninty = [student for student in students if student['grade'] == 90]
print(marks_ninty)
# Out:
# [{'name': 'anne', 'grade': 90, 'subject': 'IT'}]
